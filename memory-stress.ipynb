# %% [markdown]
# # memory stress test (credit: Klaus Reuter)

# %%
import numpy as np

# %%
# per-matrix size and per-matrix memory requirement
n = 16000
mb = n*n*8./2.**20
print("{} MB".format(mb))

# %%
# first matrix filled with 1.0
A = np.ones((n,n))

# %%
# *second* matrix, assuming 4GB limit per pod, the kernel will get killed
B = A + A

# %%
# *third* matrix, assuming 6GB limit per pod, the kernel will get killed
C = B * B

# %%
# *fourth* matrix, assuming 8GB limit per pod, the kernel will get killed
D = C - B
